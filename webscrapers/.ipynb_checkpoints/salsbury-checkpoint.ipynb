# %% [markdown]
# # template_webscraping

# %% [markdown]
# ## Load Libraries

# %%
# Selenium
import selenium
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
# Reqeusts
import requests
# Other tools
from bs4 import BeautifulSoup
from datetime import datetime
from datetime import timedelta
from datetime import date
from datetime import datetime
from datetime import timedelta
from datetime import date
import csv
import pandas as pd
import time
import json
import fnmatch
import os
import tabula
from tabula.io import read_pdf

# %% [markdown]
# ## Functions Using Requests

# %%
def requests_get_item(url, item):
    headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/70.0.3538.77 Safari/537.36"}
    if item == "html":       
        page = requests.get(url, headers = headers)
        soup = BeautifulSoup(page.text, 'html.parser')
        return(soup)
    
    elif item == "pdf":
        page = requests.get(url, headers = headers, stream=True)
        return(page)
    else:
        print("Valid Item Not Selected")

def download_pdfs(ls_pdf_urls, download_path, file_name):
    counter = 0 
    for pdf_url in ls_pdf_urls:
        counter = counter +1
        g = requests_get_item(pdf_url, "pdf")
        with open(f'{download_path}{file_name}_{counter}.pdf', 'wb') as sav:
            for chunk in g.iter_content(chunk_size=1000000):
                sav.write(chunk)
        print(f"download number: {counter}")
                
                
def convert_pdf_to_csv(pdf_directory, csv_directory):
    directory = fr'{pdf_directory}'
    directory_output = fr'{csv_directory}'
    count = 0
    for file in os.listdir(directory):        
        if file.endswith(".pdf"):
            count = count + 1 
            print(f'{directory}{file}: Conversion {count}')
            tabula.convert_into(f'{directory}{file}', f'{directory_output}{count}.csv', output_format="csv", pages='all')

# %% [markdown]
# ## Functions Using Selenium

# %%
# Define important paths
executable_path = "./aadit_chromedriver"
download_path = f"..data/handmade/salsbury/pdfs/"

# Define Routes (usually in xpaths)

def browser_instance(executable_path, headless, download_path):
    
    
    chrome_options =  Options()
    if headless:
        chrome_options.add_argument("--headless")   
    chrome_options.add_experimental_option("prefs", {
            "download.default_directory": download_path})    
    driver = webdriver.Chrome(executable_path=executable_path, options = chrome_options)
    return driver  

def signIn(driver, url, signin_field, username_field, password_field):  
    driver.get(url)
    sign_in = driver.find_element_by_xpath(signin_field)
    sign_in.click()
    email_field = driver.find_element_by_xpath(username_field)
    password_field = driver.find_element_by_xpath(password_field)
    email_field.send_keys(USERNAME)
    password_field.send_keys(PASSWORD + Keys.RETURN)

# %% [markdown]
# ## Useful Selenium Concepts
# ### Waiting until element is clickable
# button = WebDriverWait(driver, 10).until(EC.element_to_be_clickable((By.XPATH, download_all_field)))
# button.click()
#
# ### Try and Expect
# try:
#     attempt to do something
# except:
#     do this if the try doesn't work out

# %% [markdown]
# ## General Functions

# %%
def write_json_data(data_out, database_name, file_path):
        #writing data to json
        data_out = data_out
        database_name = database_name
        file = f'{file_path}/{database_name}'
        with open(file, 'w') as outfile:
            json.dump(data_out, outfile)
            
def open_json_data(file_path):    
    with open(file_path) as f:
        data = json.load(f)
    return data

# %%
# date must be in following format: 2021-08-12
def get_date(start_date, end_date):
    date_list = []
    # end_date as current data
    end_date = date.today()
    # add 60 days to start date, save that as first el in list
    start_date = datetime.strptime(start_date, '%Y-%m-%d')
    start_date = start_date + timedelta(days=60)
    start_date = (start_date.date())
    
    date_list.append(str(start_date))
    while (start_date + timedelta(days=60)) < end_date:
        start_date = start_date + timedelta(days=120)
        string_start_date = str(start_date)
        
        if (start_date + timedelta(days=60)) > end_date: 
            start_date = end_date
        date_list.append(str(start_date))
    
        
    return(date_list)
        # while start + 60 is less than today, keep adding a new date that's +120 days
        # when it's greater thant today's date, break out of the lop
    
    # next date will be 120 days after the date we just returned
    # while loop intil we hit a date that's within 60 days of today's end_date
    
dates = get_date('2019-01-03', 'end_date')
print(dates)
# Out:
# ['2019-03-04', '2019-07-02', '2019-10-30', '2020-02-27', '2020-06-26', '2020-10-24', '2021-02-21', '2021-06-21', '2021-10-12']

# %%
driver = browser_instance(executable_path, False, download_path)
driver.get("https://www.salisbury.edu/police/clery-compliance/daily-crime-and-incident-log.aspx")

# %%
results = []
for date in dates[0:1]:
#     print(date)
    driver.get("https://www.salisbury.edu/police/clery-compliance/daily-crime-and-incident-log.aspx")
    search_bar = WebDriverWait(driver, 10).until(EC.element_to_be_clickable((By.XPATH, '//*[@id="dateSearch"]')))
    submit_button = WebDriverWait(driver, 10).until(EC.element_to_be_clickable((By.XPATH, '//*[@id="dateSubmit"]')))
    
    print(date)
    print("-----")
    search_bar.send_keys(date)
    
    submit_button.click()
#     search_bar.send_keys(Keys.DELETE)
#     search_bar.send_keys(Keys.COMMAND, 'a')
#     search_bar.send_keys(Keys.BACKSPACE)
    table_finder = WebDriverWait(driver, 10).until(EC.element_to_be_clickable((By.XPATH, '//*[@id="crimebeattable"]')))
    
    html = driver.page_source
    soup = BeautifulSoup(html, 'html.parser')
    print(soup.prettify())
#     table = soup.find(id="crimebeattable")
#     rows = table.find_all('tr')
#     for row in rows[1:]:
#       cells = row.find_all('td')
#       results.append([cell.text for cell in cells])
        
# with open('1.csv','w') as output_file:
#     csvfile = csv.writer(output_file)
#     csvfile.writerow(['case', 'date_time_location','date_reported', 'incident', 'disposition'])
#     csvfile.writerows(results)
# Out:
# 2019-03-04
# -----
# <html class="md-js md-" lang="en" prefix="og: http://ogp.me/ns# fb: http://ogp.me/ns/fb#">
#  <!--<![endif]-->
#  <head>
#   <script async="" src="https://www.google-analytics.com/analytics.js" type="text/javascript">
#   </script>
#   <script async="" id="www-widgetapi-script" src="https://www.youtube.com/s/player/920e4583/www-widgetapi.vflset/www-widgetapi.js" type="text/javascript">
#   </script>
#   <script async="" src="//acdn.adnxs.com/dmp/up/pixie.js">
#   </script>
#   <meta charset="utf-8"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <meta content="width=device-width,initial-scale=1" name="viewport"/>
#   <meta content="The Salisbury University Police Department maintains a daily log of crimes reported, with only a few exceptions. The log contains the incident classification, case number, date, time, general location, and, if known, disposition of the crime. Entries are made and updated within two business days of the report. To help enable timely warnings and inclusion of incidents on the log, it is strongly encouraged to report all crimes directly to SUPD." name="description"/>
#   <meta content="Daily Crime and Incident Log, Crime Beat, crimebeat" name="keywords"/>
#   <meta content="Salisbury University" name="author"/>
#   <meta content="index, follow" name="robots"/>
#   <meta content="website" property="og:type"/>
#   <meta content="Salisbury University" property="og:site_name"/>
#   <meta content="Clery Act Compliance: Daily Crime and Incident Log" property="og:title"/>
#   <meta content="summary" name="twitter:card"/>
#   <meta content="@SalisburyU" name="twitter:site"/>
#   <meta content="Clery Act Compliance: Daily Crime and Incident Log" name="twitter:title"/>
#   <meta content="The Salisbury University Police Department maintains a daily log of crimes reported, with only a few exceptions. The log contains the incident classification, case number, date, time, general location, and, if known, disposition of the crime. Entries are made and updated within two business days of the report. To help enable timely warnings and inclusion of incidents on the log, it is strongly encouraged to report all crimes directly to SUPD." name="twitter:description"/>
#   <meta content="The Salisbury University Police Department maintains a daily log of crimes reported, with only a few exceptions. The log contains the incident classification, case number, date, time, general location, and, if known, disposition of the crime. Entries are made and updated within two business days of the report. To help enable timely warnings and inclusion of incidents on the log, it is strongly encouraged to report all crimes directly to SUPD." property="og:description"/>
#   <meta content="https://www.salisbury.edu/police/clery-compliance/daily-crime-and-incident-log.aspx" property="og:url"/>
#   <meta content="7f6c0bc3837621b440d6a14695fec234" name="cmsid"/>
#   <meta content="09/29/2021 1:23 PM" name="cmsmoddate"/>
#   <meta content="10/11/2021 2:16 AM" name="cmspubdate"/>
#   <link href="https://www.salisbury.edu/police/clery-compliance/daily-crime-and-incident-log.aspx" rel="canonical"/>
#   <title>
#    Clery Act Compliance: Daily Crime and Incident Log | Salisbury University
#   </title>
#   <link href="/_files/img/su-favicon.png" rel="icon" sizes="16x16" type="image/png"/>
#   <link href="/_files/img/su-favicon.ico" rel="icon" sizes="16x16" type="image/x-icon"/>
#   <link href="/_files/img/su-favicon.png" rel="apple-touch-icon" sizes="100x100"/>
#   <link as="font" crossorigin="anonymous" href="/_files/css/fonts/aad99a1f-7917-4dd6-bbb5-b07cedbff64f.woff2" rel="preload" type="font/woff2"/>
#   <link as="font" crossorigin="anonymous" href="/_files/css/fonts/2cd55546-ec00-4af9-aeca-4a3cd186da53.woff2" rel="preload" type="font/woff2"/>
#   <link as="font" crossorigin="anonymous" href="/_files/css/fonts/7377dbe6-f11a-4a05-b33c-bc8ce1f60f84.woff2" rel="preload" type="font/woff2"/>
#   <link as="font" crossorigin="anonymous" href="/_files/css/fonts/bc1790d7-cfa9-4990-a053-959c34ee137d.woff2" rel="preload" type="font/woff2"/>
#   <link as="style" href="/_files/css/main.css" rel="preload"/>
#   <link as="style" href="/_files/css/SU-custom-styles.css" rel="preload"/>
#   <link as="style" href="/_files/css/SU-cookie-consent.css" rel="preload"/>
#   <link href="/_files/css/main.css" rel="stylesheet" type="text/css"/>
#   <link href="/_files/css/SU-custom-styles.css" rel="stylesheet" type="text/css"/>
#   <link href="/_files/css/SU-cookie-consent.css" rel="stylesheet" type="text/css"/>
#   <script async="" src="https://tags.srv.stackadapt.com/events.js">
#   </script>
#   <script async="" src="//www.google-analytics.com/analytics.js">
#   </script>
#   <script async="" src="//siteimproveanalytics.com/js/siteanalyze_66356453.js" type="text/javascript">
#   </script>
#   <script async="" src="https://connect.facebook.net/signals/config/864458160808968?v=2.9.47&amp;r=stable">
#   </script>
#   <script async="" src="https://connect.facebook.net/signals/config/669300803786246?v=2.9.47&amp;r=stable">
#   </script>
#   <script async="" src="https://connect.facebook.net/signals/config/155413641837329?v=2.9.47&amp;r=stable">
#   </script>
#   <script async="" src="https://connect.facebook.net/en_US/fbevents.js">
#   </script>
#   <script async="" src="//www.googleadservices.com/pagead/conversion_async.js" type="text/javascript">
#   </script>
#   <script async="" src="//www.googleadservices.com/pagead/conversion_async.js" type="text/javascript">
#   </script>
#   <script async="" src="https://www.googletagmanager.com/gtag/js?id=G-WZ4WETRPSZ&amp;l=dataLayer&amp;cx=c" type="text/javascript">
#   </script>
#   <script src="https://www.youtube.com/iframe_api">
#   </script>
#   <script async="" src="https://www.googletagmanager.com/gtm.js?id=GTM-K5L7GTQ">
#   </script>
#   <script src="/_files/js/plugins/modernizr.optimized.js">
#   </script>
#   <script src="https://googleads.g.doubleclick.net/pagead/viewthroughconversion/815112049/?random=1634048116153&amp;cv=9&amp;fst=1634048116153&amp;num=1&amp;guid=ON&amp;resp=GooglemKTybQhCsO&amp;eid=376635471&amp;u_h=900&amp;u_w=1440&amp;u_ah=875&amp;u_aw=1440&amp;u_cd=30&amp;u_his=2&amp;u_tz=-240&amp;u_java=false&amp;u_nplug=5&amp;u_nmime=2&amp;gtm=2wgab0&amp;sendb=1&amp;ig=1&amp;frm=0&amp;url=https%3A%2F%2Fwww.salisbury.edu%2Fpolice%2Fclery-compliance%2Fdaily-crime-and-incident-log.aspx&amp;tiba=Clery%20Act%20Compliance%3A%20Daily%20Crime%20and%20Incident%20Log%20%7C%20Salisbury%20University&amp;hn=www.googleadservices.com&amp;async=1&amp;rfmt=3&amp;fmt=4">
#   </script>
#   <script src="https://googleads.g.doubleclick.net/pagead/viewthroughconversion/812486016/?random=1634048116154&amp;cv=9&amp;fst=1634048116154&amp;num=1&amp;guid=ON&amp;resp=GooglemKTybQhCsO&amp;eid=376635471&amp;u_h=900&amp;u_w=1440&amp;u_ah=875&amp;u_aw=1440&amp;u_cd=30&amp;u_his=2&amp;u_tz=-240&amp;u_java=false&amp;u_nplug=5&amp;u_nmime=2&amp;gtm=2wgab0&amp;sendb=1&amp;ig=1&amp;frm=0&amp;url=https%3A%2F%2Fwww.salisbury.edu%2Fpolice%2Fclery-compliance%2Fdaily-crime-and-incident-log.aspx&amp;tiba=Clery%20Act%20Compliance%3A%20Daily%20Crime%20and%20Incident%20Log%20%7C%20Salisbury%20University&amp;hn=www.googleadservices.com&amp;async=1&amp;rfmt=3&amp;fmt=4">
#   </script>
#   <script async="" src="https://mx.technolutions.net/ping?id=2cefd331-81fe-6b2f-1c75-8f57d67400c9&amp;sid=iJ9gjhGiA5YBOlfNfUgpJpvGFFFHNZnKKqes92O_6QKbY_XAm6g2PJMFb23CfJbgijVWn-M2Erbfimxb7kTrokl7WIw6h4dd9cZ4Y5AijbqNFarmvBRc2pJaSZ59tQKS&amp;hid=85779a03-098f-c168-48bf-4925810a63be">
#   </script>
#   <style>
#   </style>
#  </head>
#  <body class="level">
#   <div aria-describedby="cookieconsent:desc" aria-label="cookieconsent" aria-live="polite" class="cc-window cc-banner cc-type-info cc-theme-edgeless cc-bottom cc-color-override--1285299752 cc-invisible" role="dialog" style="">
#    <!--googleoff: all-->
#    <span class="cc-message" id="cookieconsent:desc">
#     <div aria-label="cookie message" class="cookies_div" role="region">
#      This website uses cookies to ensure the best user experience.
#     </div>
#     <a aria-label="learn more about cookies" class="cc-link" href="https://cookiesandyou.com" rel="noopener noreferrer nofollow" role="button" tabindex="0" target="_blank">
#      Learn more
#     </a>
#    </span>
#    <div class="cc-compliance">
#     <div aria-label="cookie dismiss button" class="cookies_div_dismiss" role="region">
#      <a aria-label="Got It! - dismiss cookie message" class="cc-btn cc-dismiss" role="button" tabindex="0">
#       Got It!
#      </a>
#     </div>
#    </div>
#    <!--googleon: all-->
#   </div>
#   <script>
#    (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start': new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src='https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);})(window,document,'script','dataLayer','GTM-K5L7GTQ');
#   </script>
#   <nav aria-label="accessibility navigation to skip to header, main content and footer" class="access-nav">
#    <a class="show-on-focus" href="#main">
#     Skip to Main Content
#    </a>
#    <a class="show-on-focus" href="#js-global-header">
#     Skip to Header
#    </a>
#    <a class="show-on-focus" href="#js-global-footer">
#     Skip to Footer
#    </a>
#   </nav>
#   <section aria-label="Emergency Notice" class="emergency-alert" id="js-emergency-alert">
#    <div class="emergency-alert__heading" tabindex="0">
#     COVID-19 Precautions Continue for Fall
#     <span class="emergency-alert__icon">
#      <span class="alert-icon">
#       <svg class="icon icon-exclamation-point">
#        <use xlink:href="/_files/svg/definitions.svg#icon-exclamation-point" xmlns:xlink="http://www.w3.org/1999/xlink">
#        </use>
#       </svg>
#      </span>
#     </span>
#     <svg class="icon icon-chevron-right">
#      <use xlink:href="/_files/svg/definitions.svg#icon-chevron-right" xmlns:xlink="http://www.w3.org/1999/xlink">
#      </use>
#     </svg>
#    </div>
#    <div class="emergency-alert__content" style="display: none;">
#     <div class="user-markup user-markup--alert-styles">
#      <p>
#       SU students and employees continue to take precautions to slow the spread of COVID-19. For health and safety resources, and current information, visit the
#       <a href="https://www.salisbury.edu/coronavirus">
#        SU COVID-19 webpage
#       </a>
#       .
#      </p>
#     </div>
#    </div>
#   </section>
#   <div class="container">
#    <!-- 1015155298 -->
#    <!-- header embed -->
#    <header class="global-header" id="js-global-header" role="banner">
#     <div class="row">
#      <div class="small-12 column">
#       <div class="global-header__content-wrapper clearfix">
#        <a aria-label="Salisbury University" class="global-header__logo" href="/">
#         <svg class="icon icon-su-logo">
#          <use xlink:href="/_files/svg/definitions.svg#icon-su-logo" xmlns:xlink="http://www.w3.org/1999/xlink">
#          </use>
#         </svg>
#        </a>
#        <div class="global-header__menu">
#         <nav aria-label="Primary" class="primary-navigation no-bullet" id="js-primary-navigation">
#          <ul class="primary-navigation__list clearfix no-bullet">
#           <li class="primary-navigation__list-item">
#            <a class="primary-navigation__link" href="/explore-academics/" target="_self">
#             <span class="primary-navigation__link-text">
#              Explore Academics
#             </span>
#            </a>
#            <a aria-label="Open" class="primary-navigation__child-nav-trigger" href="#">
#             <svg class="icon icon-chevron-right">
#              <use xlink:href="/_files/svg/definitions.svg#icon-chevron-right" xmlns:xlink="http://www.w3.org/1999/xlink">
#              </use>
#             </svg>
#            </a>
#            <ul class="primary-navigation__child-list clearfix no-bullet">
#             <li class="primary-navigation__child-item">
#              <a class="primary-navigation__child-link" href="/explore-academics/programs/" target="_self">
#               Find Your Program
#              </a>
#             </li>
#             <li class="primary-navigation__child-item">
#              <a class="primary-navigation__child-link" href="https://www.salisbury.edu/explore-academics/colleges-schools-and-departments.aspx" target="_self">
#               Colleges &amp; Schools
#              </a>
#             </li>
#             <li class="primary-navigation__child-item">
#              <a class="primary-navigation__child-link" href="https://www.salisbury.edu/explore-academics/graduate-studies.aspx" target="_self">
#               Graduate Studies
#              </a>
#             </li>
#             <li class="primary-navigation__child-item">
#              <a class="primary-navigation__child-link" href="/explore-academics/english-lang-institute/" target="_self">
#               English Language Institute
#              </a>
#             </li>
#             <li class="primary-navigation__child-item">
#              <a class="primary-navigation__child-link" href="https://www.salisbury.edu/explore-academics/student-resources.aspx" target="_self">
#               Libraries &amp; Academic Resources
#              </a>
#             </li>
#             <li class="primary-navigation__child-item">
#              <a class="primary-navigation__child-link" href="https://www.salisbury.edu/explore-academics/our-faculty.aspx" target="_self">
#               Our Faculty
#              </a>
#             </li>
#             <li class="primary-navigation__child-item">
#              <a class="primary-navigation__child-link" href="/explore-academics/research/" target="_self">
#               Research
#              </a>
#             </li>
#             <li class="primary-navigation__child-item">
#              <a class="primary-navigation__child-link" href="https://www.salisbury.edu/administration/academic-affairs/satellite-programs.aspx" target="_self">
#               Satellite Programs
#              </a>
#             </li>
#             <li class="primary-navigation__child-item">
#              <a class="primary-navigation__child-link" href="https://www.salisbury.edu/explore-academics/study-abroad.aspx" target="_self">
#               Study Abroad
#              </a>
#             </li>
#             <li class="primary-navigation__child-item">
#              <a class="primary-navigation__child-link" href="https://www.salisbury.edu/explore-academics/internships.aspx" target="_self">
#               Internships
#              </a>
#             </li>
#            </ul>
#           </li>
#           <li class="primary-navigation__list-item">
#            <a class="primary-navigation__link" href="/become-a-student/" target="_self">
#             <span class="primary-navigation__link-text">
#              Become a Student
#             </span>
#            </a>
#            <a aria-label="Open" class="primary-navigation__child-nav-trigger" href="#">
#             <svg class="icon icon-chevron-right">
#              <use xlink:href="/_files/svg/definitions.svg#icon-chevron-right" xmlns:xlink="http://www.w3.org/1999/xlink">
#              </use>
#             </svg>
#            </a>
#            <ul class="primary-navigation__child-list clearfix no-bullet">
#             <li class="primary-navigation__child-item">
#              <a class="primary-navigation__child-link" href="https://www.salisbury.edu/become-a-student/visit-campus.aspx" target="_self">
#               Visit Campus
#              </a>
#             </li>
#             <li class="primary-navigation__child-item">
#              <a class="primary-navigation__child-link" href="/admissions/freshman-students/" target="_self">
#               Apply - Freshman
#              </a>
#             </li>
#             <li class="primary-navigation__child-item">
#              <a class="primary-navigation__child-link" href="/admissions/transfer-students/" target="_self">
#               Apply - Transfer
#              </a>
#             </li>
#             <li class="primary-navigation__child-item">
#              <a class="primary-navigation__child-link" href="https://www.salisbury.edu/administration/academic-affairs/graduate-studies-and-research/graduate-studies/graduate-admissions.aspx" target="_self">
#               Apply - Graduate
#              </a>
#             </li>
#             <li class="primary-navigation__child-item">
#              <a class="primary-navigation__child-link" href="/admissions/international-students/" target="_self">
#               Apply - International
#              </a>
#             </li>
#             <li class="primary-navigation__child-item">
#              <a class="primary-navigation__child-link" href="/become-a-student/apply-satellite-programs/" target="_self">
#               Apply – Satellite Programs
#              </a>
#             </li>
#             <li class="primary-navigation__child-item">
#              <a class="primary-navigation__child-link" href="/administration/academic-affairs/registrar/non-degree/" target="_self">
#               Apply – Non-Degree
#              </a>
#             </li>
#             <li class="primary-navigation__child-item">
#              <a class="primary-navigation__child-link" href="/become-a-student/admitted-students/" target="_self">
#               Admitted Students
#              </a>
#             </li>
#            </ul>
#           </li>
#           <li class="primary-navigation__list-item">
#            <a class="primary-navigation__link" href="/afford-college/" target="_self">
#             <span class="primary-navigation__link-text">
#              Afford College
#             </span>
#            </a>
#            <a aria-label="Open" class="primary-navigation__child-nav-trigger" href="#">
#             <svg class="icon icon-chevron-right">
#              <use xlink:href="/_files/svg/definitions.svg#icon-chevron-right" xmlns:xlink="http://www.w3.org/1999/xlink">
#              </use>
#             </svg>
#            </a>
#            <ul class="primary-navigation__child-list clearfix no-bullet">
#             <li class="primary-navigation__child-item">
#              <a class="primary-navigation__child-link" href="https://www.salisbury.edu/afford-college/tuition-and-fees.aspx" target="_self">
#               Tuition &amp; Fees
#              </a>
#             </li>
#             <li class="primary-navigation__child-item">
#              <a class="primary-navigation__child-link" href="https://www.salisbury.edu/afford-college/how-to-apply.aspx" target="_self">
#               How to Apply for Aid
#              </a>
#             </li>
#             <li class="primary-navigation__child-item">
#              <a class="primary-navigation__child-link" href="https://www.salisbury.edu/afford-college/types-of-aid.aspx" target="_self">
#               Types of Aid
#              </a>
#             </li>
#             <li class="primary-navigation__child-item">
#              <a class="primary-navigation__child-link" href="https://www.salisbury.edu/afford-college/parents-and-family.aspx" target="_self">
#               Parents &amp; Family
#              </a>
#             </li>
#            </ul>
#           </li>
#           <li class="primary-navigation__list-item">
#            <a class="primary-navigation__link" href="/experience-campus/" target="_self">
#             <span class="primary-navigation__link-text">
#              Experience Campus
#             </span>
#            </a>
#            <a aria-label="Open" class="primary-navigation__child-nav-trigger" href="#">
#             <svg class="icon icon-chevron-right">
#              <use xlink:href="/_files/svg/definitions.svg#icon-chevron-right" xmlns:xlink="http://www.w3.org/1999/xlink">
#              </use>
#             </svg>
#            </a>
#            <ul class="primary-navigation__child-list clearfix no-bullet">
#             <li class="primary-navigation__child-item">
#              <a class="primary-navigation__child-link" href="https://www.salisbury.edu/experience-campus/diversity-and-inclusion.aspx" target="_self">
#               Diversity &amp; Inclusion
#              </a>
#             </li>
#             <li class="primary-navigation__child-item">
#              <a class="primary-navigation__child-link" href="https://www.salisbury.edu/experience-campus/residence-life.aspx" target="_self">
#               Housing &amp; Residence Life
#              </a>
#             </li>
#             <li class="primary-navigation__child-item">
#              <a class="primary-navigation__child-link" href="https://www.salisbury.edu/experience-campus/university-dining.aspx" target="_self">
#               University Dining
#              </a>
#             </li>
#             <li class="primary-navigation__child-item">
#              <a class="primary-navigation__child-link" href="/experience-campus/athletics/" target="_self">
#               Athletics
#              </a>
#             </li>
#             <li class="primary-navigation__child-item">
#              <a class="primary-navigation__child-link" href="https://www.salisbury.edu/experience-campus/clubs-and-organizations.aspx" target="_self">
#               Clubs &amp; Organizations
#              </a>
#             </li>
#             <li class="primary-navigation__child-item">
#              <a aria-label="View News &amp; Events for the University" class="primary-navigation__child-link" href="https://www.salisbury.edu/experience-campus/news-and-events.aspx" target="_self">
#               News &amp; Events
#              </a>
#             </li>
#             <li class="primary-navigation__child-item">
#              <a class="primary-navigation__child-link" href="https://www.salisbury.edu/experience-campus/student-services.aspx" target="_self">
#               Student Services
#              </a>
#             </li>
#             <li class="primary-navigation__child-item">
#              <a aria-label="Explore Salisbury University's World Class Facilities" class="primary-navigation__child-link" href="https://www.salisbury.edu/experience-campus/facilities.aspx" target="_self">
#               Facilities
#              </a>
#             </li>
#            </ul>
#           </li>
#           <li class="primary-navigation__list-item">
#            <a class="primary-navigation__link" href="/discover-su/" target="_self">
#             <span class="primary-navigation__link-text">
#              Discover SU
#             </span>
#            </a>
#            <a aria-label="Open" class="primary-navigation__child-nav-trigger" href="#">
#             <svg class="icon icon-chevron-right">
#              <use xlink:href="/_files/svg/definitions.svg#icon-chevron-right" xmlns:xlink="http://www.w3.org/1999/xlink">
#              </use>
#             </svg>
#            </a>
#            <ul class="primary-navigation__child-list clearfix no-bullet">
#             <li class="primary-navigation__child-item">
#              <a class="primary-navigation__child-link" href="https://www.salisbury.edu/discover-su/outcomes.aspx" target="_self">
#               Outcomes &amp; Rankings
#              </a>
#             </li>
#             <li class="primary-navigation__child-item">
#              <a class="primary-navigation__child-link" href="https://www.salisbury.edu/discover-su/mission-values.aspx" target="_self">
#               Mission &amp; Values
#              </a>
#             </li>
#             <li class="primary-navigation__child-item">
#              <a class="primary-navigation__child-link" href="https://www.salisbury.edu/discover-su/campus-leadership.aspx" target="_self">
#               Campus Leadership
#              </a>
#             </li>
#             <li class="primary-navigation__child-item">
#              <a class="primary-navigation__child-link" href="/discover-su/campus-history/" target="_self">
#               Campus History
#              </a>
#             </li>
#             <li class="primary-navigation__child-item">
#              <a class="primary-navigation__child-link" href="/discover-su/community-outreach/" target="_self">
#               Community Outreach
#              </a>
#             </li>
#             <li class="primary-navigation__child-item">
#              <a class="primary-navigation__child-link" href="https://www.salisbury.edu/discover-su/campus-spotlights.aspx" target="_self">
#               Campus Spotlights
#              </a>
#             </li>
#             <li class="primary-navigation__child-item">
#              <a class="primary-navigation__child-link" href="https://www.salisbury.edu/discover-su/offices.aspx" target="_self">
#               Offices and Departments
#              </a>
#             </li>
#             <li class="primary-navigation__child-item">
#              <a class="primary-navigation__child-link" href="https://www.salisbury.edu/discover-su/our-region.aspx" target="_self">
#               Our Region
#              </a>
#             </li>
#             <li class="primary-navigation__child-item">
#              <a class="primary-navigation__child-link" href="/discover-su/campus-map/" target="_self">
#               Campus Map &amp; Directions
#              </a>
#             </li>
#            </ul>
#           </li>
#          </ul>
#         </nav>
#         <nav aria-label="Secondary" class="secondary-navigation">
#          <ul class="secondary-navigation__list no-bullet">
#           <li class="secondary-navigation__list-item">
#            <a class="secondary-navigation__link" href="/current-students/" target="_self">
#             Current Students
#            </a>
#           </li>
#           <li class="secondary-navigation__list-item">
#            <a class="secondary-navigation__link" href="/employees/" target="_self">
#             Faculty &amp; Staff
#            </a>
#           </li>
#           <li class="secondary-navigation__list-item">
#            <a aria-label="Alumni (This link opens in a new window)" class="secondary-navigation__link" href="https://campaign.salisbury.edu/" target="_blank">
#             Alumni
#            </a>
#           </li>
#           <li class="secondary-navigation__list-item">
#            <a class="secondary-navigation__link" href="/donors-friends-and-family/" target="_self">
#             Donors, Friends &amp; Families
#            </a>
#           </li>
#          </ul>
#         </nav>
#         <a aria-label="Close main menu" class="global-header__close-trigger" href="#" id="js-close-menu-trigger">
#          <svg class="icon icon-close">
#           <use xlink:href="/_files/svg/definitions.svg#icon-close" xmlns:xlink="http://www.w3.org/1999/xlink">
#           </use>
#          </svg>
#         </a>
#        </div>
#        <a aria-label="Open search menu" class="global-header__search-trigger" href="#" id="js-search-trigger">
#         <svg class="icon icon-search">
#          <use xlink:href="/_files/svg/definitions.svg#icon-search" xmlns:xlink="http://www.w3.org/1999/xlink">
#          </use>
#         </svg>
#        </a>
#        <div class="site-search" id="js-site-search">
#         <div class="row">
#          <div class="small-12 medium-12 large-10 large-centered column">
#           <form action="/search/" class="site-search__form" id="searchbox_012922190682254864109:x5_7wzea6la" role="search">
#            <input name="cx" type="hidden" value="012922190682254864109:x5_7wzea6la"/>
#            <input name="cof" type="hidden" value="FORID:11"/>
#            <fieldset class="site-search__fieldset">
#             <legend class="site-search__legend show-for-sr">
#              Search Salisbury University
#             </legend>
#             <label class="site-search__label show-for-sr" for="site-search-input">
#              Search
#             </label>
#             <input class="site-search__input" id="site-search-input" name="q" placeholder="Pages and people" type="text"/>
#             <button aria-label="Search Salisbury University" class="site-search__button button--has-icon" id="js-site-search-button" tabindex="0" type="submit">
#              <svg class="icon icon-search">
#               <use xlink:href="/_files/svg/definitions.svg#icon-search" xmlns:xlink="http://www.w3.org/1999/xlink">
#               </use>
#              </svg>
#              <span class="button__text">
#               Search
#              </span>
#             </button>
#             <div class="common-searches" id="common-searches">
#              <div class="list-header">
#               Common Searches
#              </div>
#              <div class="first-list">
#               <ul class="no-bullet">
#                <li>
#                 <a class="common-searches__link" href="/become-a-student/">
#                  Admissions
#                 </a>
#                </li>
#                <li>
#                 <a class="common-searches__link" href="/calendars/">
#                  Campus Calendars
#                 </a>
#                </li>
#                <li>
#                 <a class="common-searches__link" href="/events/">
#                  Events
#                 </a>
#                </li>
#                <li>
#                 <a class="common-searches__link" href="/news/">
#                  News
#                 </a>
#                </li>
#                <li>
#                 <a class="common-searches__link" href="/explore-academics/programs/">
#                  Majors &amp; Minors
#                 </a>
#                </li>
#                <li>
#                 <a class="common-searches__link" href="https://campaign.salisbury.edu">
#                  We Are SU: The Campaign for Salisbury University
#                 </a>
#                </li>
#               </ul>
#              </div>
#              <div class="second-list">
#               <ul class="no-bullet">
#                <li>
#                 <a class="common-searches__link" href="/gullnet-login.aspx">
#                  GullNet
#                 </a>
#                </li>
#                <li>
#                 <a class="common-searches__link" href="/administration/administration-and-finance-offices/information-technology/help-desk/">
#                  IT Help Desk
#                 </a>
#                </li>
#                <li>
#                 <a class="common-searches__link" href="/libraries/services/mobile-printing.aspx">
#                  Mobile Printing
#                 </a>
#                </li>
#                <li>
#                 <a class="common-searches__link" href="/administration/academic-affairs/instructional-design-delivery/cms/">
#                  MyClasses
#                 </a>
#                </li>
#                <li>
#                 <a class="common-searches__link" href="/administration/academic-affairs/registrar/">
#                  Registrar
#                 </a>
#                </li>
#               </ul>
#              </div>
#              <div class="third-list">
#               <ul class="no-bullet">
#                <li>
#                 <a class="common-searches__link" href="https://www.salisbury.edu/coronavirus/">
#                  COVID19/Coronavirus
#                 </a>
#                </li>
#                <li>
#                 <a class="common-searches__link" href="/faculty-and-staff/">
#                  Directory (Faculty &amp; Staff)
#                 </a>
#                </li>
#                <li>
#                 <a class="common-searches__link" href="/discover-su/offices.aspx">
#                  Offices &amp; Departments
#                 </a>
#                </li>
#                <li>
#                 <a class="common-searches__link" href="/discover-su/campus-map/">
#                  Map of the Campus
#                 </a>
#                </li>
#                <li>
#                 <a class="common-searches__link" href="/administration/administration-and-finance-offices/financial-services/accounts-receivable-cashiers-office/parking-services/visitor-permits.aspx">
#                  Visitor Parking
#                 </a>
#                </li>
#               </ul>
#              </div>
#             </div>
#            </fieldset>
#           </form>
#           <a aria-label="Close search menu" class="site-search__close-trigger" href="#" id="js-close-search-trigger">
#            <svg class="icon icon-close">
#             <use xlink:href="/_files/svg/definitions.svg#icon-close" xmlns:xlink="http://www.w3.org/1999/xlink">
#             </use>
#            </svg>
#           </a>
#          </div>
#         </div>
#        </div>
#        <a aria-label="Open main menu" class="hamburger-menu" href="#" id="js-hamburger-menu">
#         <span class="hamburger-menu__top">
#         </span>
#         <span class="hamburger-menu__middle">
#         </span>
#         <span class="hamburger-menu__bottom">
#         </span>
#        </a>
#       </div>
#      </div>
#     </div>
#    </header>
#    <!-- end header embed -->
#    <!-- 1015155298 (0 ms) -->
#    <main class="main main--level" id="main">
#     <div class="masthead masthead--banner" id="js-masthead">
#      <div class="masthead__media-container">
#       <div aria-label="Salisbury University Holloway Hall" class="image masthead__image default__image" role="img" style="background-image: url('https://www.salisbury.edu/_images/holloway-hall-masthead-default.jpg')" title="Salisbury University Holloway Hall">
#       </div>
#      </div>
#     </div>
#     <div class="main__content">
#      <div class="row">
#       <div class="small-12 medium-12 large-12 xlarge-10 xlarge-centered column">
#        <nav aria-label="Breadcrumb" class="breadcrumbs">
#         <ol class="breadcrumbs__list no-bullet">
#          <li class="breadcrumbs__item">
#           <a aria-label="Go back to the Salisbury University home page" class="breadcrumbs__link breadcrumbs__link--home" href="/">
#            <svg class="icon icon-home">
#             <use xlink:href="/_files/svg/definitions.svg#icon-home" xmlns:xlink="http://www.w3.org/1999/xlink">
#             </use>
#            </svg>
#           </a>
#          </li>
#          <li class="breadcrumbs__item">
#           <a class="breadcrumbs__link" href="/police/">
#            University Police
#           </a>
#          </li>
#          <li class="breadcrumbs__item">
#           <a class="breadcrumbs__link" href="/police/clery-compliance/">
#            Clery Act Compliance
#           </a>
#          </li>
#          <li class="breadcrumbs__item">
#           <span class="breadcrumbs__current-item">
#            Daily Crime and Incident Log
#           </span>
#          </li>
#         </ol>
#        </nav>
#       </div>
#      </div>
#      <div class="row">
#       <div class="small-12 medium-12 large-12 xlarge-10 xlarge-centered column">
#        <section aria-labelledby="pageHeading" class="component">
#         <div class="user-markup">
#          <div class="row">
#           <div class="small-12 column">
#            <h1 id="pageHeading">
#             Daily Crime and Incident Log
#            </h1>
#           </div>
#          </div>
#         </div>
#        </section>
#        <section aria-label="WYSIWYG 1" class="component">
#         <div class="user-markup">
#          <p>
#           The Salisbury University Police Department maintains a daily log of crimes reported, with only a few exceptions. This log contains the incident classification, case number, date, time, general location, and, if known, disposition of the crime. Entries are made and updated within two business days of the report. To help enable timely warnings and inclusion of incidents on the log, it is strongly encouraged to report all crimes directly to SUPD.
#          </p>
#          <p>
#           According to Federal Law, an institution may temporarily withhold any of the required fields of entry, i.e., the incident classification, case number, date, time, location, and/or disposition if any of the following conditions apply:
#          </p>
#          <ul>
#           <li>
#            The disclosure is prohibited by law.
#           </li>
#           <li>
#            If disclosure would jeopardize the confidentially of the victim.
#           </li>
#           <li>
#            If disclosure would jeopardize an ongoing criminal investigation and/or the safety of an individual.
#           </li>
#           <li>
#            If the disclosure would cause a suspect to flee or evade detection.
#           </li>
#           <li>
#            If disclosure would result in the destruction of evidence.
#           </li>
#          </ul>
#          <p>
#           When the investigation concludes these exceptions no longer apply, the daily log will be updated with the required fields.
#          </p>
#          <link href="/_services/_files/datatables/datatables.min.css" rel="stylesheet" type="text/css"/>
#          <link href="/_services/_files/datatables/datatables-SU.css" rel="stylesheet" type="text/css"/>
#          <script src="/_services/_files/jquery/jquery-3.3.1.min.js">
#          </script>
#          <script src="/_services/_files/jquery/jquery-ui-1.10.3.min.js">
#          </script>
#          <script src="/_services/_files/datatables/datatables.min.js">
#          </script>
#          <script src="/_services/police/crimebeat.js">
#          </script>
#          <link href="/_services/police/crimebeat.css" rel="stylesheet" type="text/css"/>
#          <div class="crimebeat">
#           <div class="crimebeat">
#            <div class="dateSearch_div">
#             <div>
#              <label for="dateSearch">
#               <strong>
#                Search by Date:
#               </strong>
#              </label>
#              <input class="hasDatepicker" id="dateSearch" name="dateSearch" type="text"/>
#              <input class="button" id="dateSubmit" name="dateSubmit" type="Submit" value="Submit"/>
#              <input class="button" id="resetSearch" name="resetSearch" type="reset" value="Clear"/>
#             </div>
#             <div>
#              <em>
#               (This page will show incidents 60 days prior to and 60 days after the date selected)
#              </em>
#             </div>
#            </div>
#           </div>
#          </div>
#          <style>
#           <!--
# #crimebeattable th.Case_No {width: 8rem !important;}
# #crimebeattable th.DateTime_and_Location {width: 25rem !important;}
# #crimebeattable td.Case_No {/*white-space: nowrap !important;*/}
# -->
#          </style>
#          <div class="crimebeat">
#           <div class="table-wrapper">
#            <div class="table-wrapper">
#             <div class="dataTables_wrapper no-footer" id="crimebeattable_wrapper">
#              <div>
#               <div class="dataTables_length" id="crimebeattable_length">
#                <label>
#                 Show
#                 <select aria-controls="crimebeattable" class="" name="crimebeattable_length">
#                  <option value="-1">
#                   All
#                  </option>
#                  <option value="50">
#                   50
#                  </option>
#                  <option value="25">
#                   25
#                  </option>
#                 </select>
#                 entries
#                </label>
#               </div>
#               <div aria-live="polite" class="dataTables_info" id="crimebeattable_info" role="status">
#                Showing 1 to 72 of 72 entries
#               </div>
#               <div class="dataTables_filter" id="crimebeattable_filter">
#                <label>
#                 Filter:
#                 <input aria-controls="crimebeattable" class="" placeholder="" type="search"/>
#                </label>
#               </div>
#               <div>
#                <table aria-describedby="crimebeattable_info" class="responsive-table dataTable no-footer" id="crimebeattable" role="grid" style="width: 100%;">
#                 <thead>
#                  <tr role="row">
#                   <th aria-controls="crimebeattable" aria-label="Case: activate to sort column ascending" class="case Case_No sorting" colspan="1" rowspan="1" style="width: 188px;" tabindex="0">
#                    Case
#                   </th>
#                   <th aria-controls="crimebeattable" aria-label="Date/Time and Location: activate to sort column ascending" aria-sort="descending" class="datetime_location DateTime_and_Location sorting_desc" colspan="1" rowspan="1" style="width: 187px;" tabindex="0">
#                    Date/Time and Location
#                   </th>
#                   <th aria-controls="crimebeattable" aria-label="Date Reported: activate to sort column ascending" class="datereported Report_Date sorting" colspan="1" rowspan="1" style="width: 186px;" tabindex="0">
#                    Date Reported
#                   </th>
#                   <th aria-controls="crimebeattable" aria-label="Incident: activate to sort column ascending" class="incident Incident_Type sorting" colspan="1" rowspan="1" style="width: 187px;" tabindex="0">
#                    Incident
#                   </th>
#                   <th aria-controls="crimebeattable" aria-label="Disposition: activate to sort column ascending" class="disposition Disposition sorting" colspan="1" rowspan="1" style="width: 187px;" tabindex="0">
#                    Disposition
#                   </th>
#                  </tr>
#                 </thead>
#                 <tbody>
#                  <tr class="odd">
#                   <td class="Case_No" data-th="Case">
#                    21-00233
#                   </td>
#                   <td class="DateTime_and_Location sorting_1" data-th="Date/Time and Location">
#                    10/09/2021 04:10 to 04:10
#                    <br/>
#                    Nanticoke Hall
#                   </td>
#                   <td class="Report_Date" data-th="Date Reported">
#                    10/09/2021
#                   </td>
#                   <td class="Incident_Type" data-th="Incident">
#                    Alcohol Violation
#                   </td>
#                   <td class="Disposition" data-th="Disposition">
#                    CLOSED
#                   </td>
#                  </tr>
#                  <tr class="even">
#                   <td class="Case_No" data-th="Case">
#                    21-00232
#                   </td>
#                   <td class="DateTime_and_Location sorting_1" data-th="Date/Time and Location">
#                    10/08/2021 17:55 to 17:55
#                    <br/>
#                    Commons Building
#                   </td>
#                   <td class="Report_Date" data-th="Date Reported">
#                    10/08/2021
#                   </td>
#                   <td class="Incident_Type" data-th="Incident">
#                    Miscellaneous
#                   </td>
#                   <td class="Disposition" data-th="Disposition">
#                    CLOSED
#                   </td>
#                  </tr>
#                  <tr class="odd">
#                   <td class="Case_No" data-th="Case">
#                    21-00231
#                   </td>
#                   <td class="DateTime_and_Location sorting_1" data-th="Date/Time and Location">
#                    10/07/2021 12:30 to 12:30
#                    <br/>
#                    Parking Lot B
#                   </td>
#                   <td class="Report_Date" data-th="Date Reported">
#                    10/07/2021
#                   </td>
#                   <td class="Incident_Type" data-th="Incident">
#                    Traffic Accident-Non Injury
#                   </td>
#                   <td class="Disposition" data-th="Disposition">
#                    CLOSED
#                   </td>
#                  </tr>
#                  <tr class="even">
#                   <td class="Case_No" data-th="Case">
#                    21-00230
#                   </td>
#                   <td class="DateTime_and_Location sorting_1" data-th="Date/Time and Location">
#                    10/06/2021 21:25 to 21:25
#                    <br/>
#                    Wayne Street/Parking Garage
#                   </td>
#                   <td class="Report_Date" data-th="Date Reported">
#                    10/06/2021
#                   </td>
#                   <td class="Incident_Type" data-th="Incident">
#                    Malicious Destruction of Property
#                   </td>
#                   <td class="Disposition" data-th="Disposition">
#                    OPEN
#                   </td>
#                  </tr>
#                  <tr class="odd">
#                   <td class="Case_No" data-th="Case">
#                    21-00229
#                   </td>
#                   <td class="DateTime_and_Location sorting_1" data-th="Date/Time and Location">
#                    10/06/2021 19:15 to 19:15
#                    <br/>
#                    Wayne Street
#                   </td>
#                   <td class="Report_Date" data-th="Date Reported">
#                    10/06/2021
#                   </td>
#                   <td class="Incident_Type" data-th="Incident">
#                    Traffic Accident-Pedestrian Injury
#                   </td>
#                   <td class="Disposition" data-th="Disposition">
#                    CLOSED
#                   </td>
#                  </tr>
#                  <tr class="even">
#                   <td class="Case_No" data-th="Case">
#                    21-00228
#                   </td>
#                   <td class="DateTime_and_Location sorting_1" data-th="Date/Time and Location">
#                    10/06/2021 18:22 to 18:22
#                    <br/>
#                    Choptank Hall
#                   </td>
#                   <td class="Report_Date" data-th="Date Reported">
#                    10/06/2021
#                   </td>
#                   <td class="Incident_Type" data-th="Incident">
#                    CDS Complaint
#                   </td>
#                   <td class="Disposition" data-th="Disposition">
#                    CLOSED
#                   </td>
#                  </tr>
#                  <tr class="odd">
#                   <td class="Case_No" data-th="Case">
#                    21-00227
#                   </td>
#                   <td class="DateTime_and_Location sorting_1" data-th="Date/Time and Location">
#                    10/04/2021 10:00 to 10:00
#                    <br/>
#                    Division Street Building
#                   </td>
#                   <td class="Report_Date" data-th="Date Reported">
#                    10/04/2021
#                   </td>
#                   <td class="Incident_Type" data-th="Incident">
#                    Hazardous Materials- Leak
#                   </td>
#                   <td class="Disposition" data-th="Disposition">
#                    CLOSED
#                   </td>
#                  </tr>
#                  <tr class="even">
#                   <td class="Case_No" data-th="Case">
#                    21-00225
#                   </td>
#                   <td class="DateTime_and_Location sorting_1" data-th="Date/Time and Location">
#                    10/02/2021 18:00 to 18:00
#                    <br/>
#                    Unknown
#                   </td>
#                   <td class="Report_Date" data-th="Date Reported">
#                    10/02/2021
#                   </td>
#                   <td class="Incident_Type" data-th="Incident">
#                    Suspicious Circumstances
#                   </td>
#                   <td class="Disposition" data-th="Disposition">
#                    SUSPENDED
#                   </td>
#                  </tr>
#                  <tr class="odd">
#                   <td class="Case_No" data-th="Case">
#                    21-00226
#                   </td>
#                   <td class="DateTime_and_Location sorting_1" data-th="Date/Time and Location">
#                    10/02/2021 00:00 to 10/02/2021 00:00
#                    <br/>
#                    Campus Wide
#                   </td>
#                   <td class="Report_Date" data-th="Date Reported">
#                    10/04/2021
#                   </td>
#                   <td class="Incident_Type" data-th="Incident">
#                    Suspicious Circumstances
#                   </td>
#                   <td class="Disposition" data-th="Disposition">
#                    CLOSED
#                   </td>
#                  </tr>
#                  <tr class="even">
#                   <td class="Case_No" data-th="Case">
#                    21-00222
#                   </td>
#                   <td class="DateTime_and_Location sorting_1" data-th="Date/Time and Location">
#                    09/30/2021 11:56 to 11:56
#                    <br/>
#                    Holloway Hall-Ext
#                   </td>
#                   <td class="Report_Date" data-th="Date Reported">
#                    09/30/2021
#                   </td>
#                   <td class="Incident_Type" data-th="Incident">
#                    Traffic Accident-Non Injury
#                   </td>
#                   <td class="Disposition" data-th="Disposition">
#                    CLOSED
#                   </td>
#                  </tr>
#                  <tr class="odd">
#                   <td class="Case_No" data-th="Case">
# ...
#   </script>
#   <script id="" type="text/javascript">
#    (function(){var a=GTM_UTILS.getCookie("gclid");!a&&(a=GTM_UTILS.getParameterByName("gclid"))&&(dataLayer.push({event:"gclidReturned",gclid:a}),GTM_UTILS.setCookie("gclid",a,5256E3))})();
#   </script>
#   <script id="" type="text/javascript">
#    var cname="localHour",cookieCheck=GTM_UTILS.getCookie(cname);if(!cookieCheck){var date=new Date,dateStr=date.toString(),dateArr=dateStr.split(" "),localHour=dateArr[4].split(":")[0],localTime=localHour;dataLayer.push({event:"setLocalTime",localHour:localTime});GTM_UTILS.setCookie(cname,localTime,google_tag_manager["GTM-K5L7GTQ"].macro(7))};
#   </script>
#   <script id="" type="text/javascript">
#    (function(){var a=GTM_UTILS.getCookie("msclkid");!a&&(a=GTM_UTILS.getParameterByName("msclkid"))&&(dataLayer.push({event:"msclkidReturned",msclkid:a}),GTM_UTILS.setCookie("msclkid",a,5256E3))})();
#   </script>
#   <script id="" src="https://gogulls.salisbury.edu/ping" type="text/javascript">
#   </script>
#   <script id="" type="text/javascript">
#    !function(b,e,f,g,a,c,d){b.saq||(a=b.saq=function(){a.callMethod?a.callMethod.apply(a,arguments):a.queue.push(arguments)},b._saq||(b._saq=a),a.push=a,a.loaded=!0,a.version="1.0",a.queue=[],c=e.createElement(f),c.async=!0,c.src=g,d=e.getElementsByTagName(f)[0],d.parentNode.insertBefore(c,d))}(window,document,"script","https://tags.srv.stackadapt.com/events.js");saq("rt","yFJpuvi6GJw98MeZtgfZsg");
#   </script>
#   <noscript>
#    <img alt="" height="1" src="https://tags.srv.stackadapt.com/rt?sid=yFJpuvi6GJw98MeZtgfZsg" width="1"/>
#   </noscript>
#   <script id="" type="text/javascript">
#    !function(b,e,f,g,a,c,d){b.fbq||(a=b.fbq=function(){a.callMethod?a.callMethod.apply(a,arguments):a.queue.push(arguments)},b._fbq||(b._fbq=a),a.push=a,a.loaded=!0,a.version="2.0",a.queue=[],c=e.createElement(f),c.async=!0,c.src=g,d=e.getElementsByTagName(f)[0],d.parentNode.insertBefore(c,d))}(window,document,"script","https://connect.facebook.net/en_US/fbevents.js");fbq("init","669300803786246");fbq("track","PageView");
#   </script>
#   <noscript>
#    <img alt="" height="1" src="https://www.facebook.com/tr?id=669300803786246&amp;ev=PageView&amp;noscript=1" style="display:none" width="1"/>
#   </noscript>
#   <script id="" type="text/javascript">
#    fbq("trackSingle","669300803786246","Digital Boost - EM - DB - Retargeting");
#   </script>
#   <script id="" type="text/javascript">
#    !function(a,b){if(!a.pixie){var c=a.pixie=function(d,e,f){c.actionQueue.push({action:d,actionValue:e,params:f})};c.actionQueue=[];a=b.createElement("script");a.async=!0;a.src="//acdn.adnxs.com/dmp/up/pixie.js";b=b.getElementsByTagName("head")[0];b.insertBefore(a,b.firstChild)}}(window,document);pixie("init","77e6f044-cf8d-44bd-bd28-94542a6d7ed3");
#   </script>
#   <script id="" type="text/javascript">
#    pixie("event","PageView");
#   </script>
#   <noscript>
#    <img alt="" src="https://ib.adnxs.com/pixie?pi=77e6f044-cf8d-44bd-bd28-94542a6d7ed3&amp;e=PageView&amp;script=0"/>
#   </noscript>
#   <script id="" type="text/javascript">
#    !function(b,e,f,g,a,c,d){b.fbq||(a=b.fbq=function(){a.callMethod?a.callMethod.apply(a,arguments):a.queue.push(arguments)},b._fbq||(b._fbq=a),a.push=a,a.loaded=!0,a.version="2.0",a.queue=[],c=e.createElement(f),c.async=!0,c.src=g,d=e.getElementsByTagName(f)[0],d.parentNode.insertBefore(c,d))}(window,document,"script","https://connect.facebook.net/en_US/fbevents.js");fbq("init","864458160808968");fbq("track","PageView");
#   </script>
#   <noscript>
#    <img alt="" height="1" src="https://www.facebook.com/tr?id=864458160808968&amp;ev=PageView&amp;noscript=1" style="display:none" width="1"/>
#   </noscript>
#   <script id="" type="text/javascript">
#    !function(b,e,f,g,a,c,d){b.saq||(a=b.saq=function(){a.callMethod?a.callMethod.apply(a,arguments):a.queue.push(arguments)},b._saq||(b._saq=a),a.push=a,a.loaded=!0,a.version="1.0",a.queue=[],c=e.createElement(f),c.async=!0,c.src=g,d=e.getElementsByTagName(f)[0],d.parentNode.insertBefore(c,d))}(window,document,"script","https://tags.srv.stackadapt.com/events.js");saq("rt","jQYdNOugvmrcP2VwPyY2wD");
#   </script>
#   <noscript>
#    <img height="1" src="https://tags.srv.stackadapt.com/rt?sid=jQYdNOugvmrcP2VwPyY2wD" width="1"/>
#   </noscript>
#   <script id="" type="text/javascript">
#    (function(){var b=google_tag_manager["GTM-K5L7GTQ"].macro(8),a=GTM_UTILS.getCookie(b);a||(a=GTM_UTILS.uuid());GTM_UTILS.setCookie(b,a,google_tag_manager["GTM-K5L7GTQ"].macro(9));dataLayer.push({event:"sessionLogicComplete"})})();
#   </script>
#   <script id="" type="text/javascript">
#    (function(){function c(a,b){for(var c=0;c<b.length;c++){var d=b[c];if(-1<a.indexOf(d))return!0}return!1}var b=google_tag_manager["GTM-K5L7GTQ"].macro(11),e=GTM_UTILS.getCookie("persona"),d=document.location.href;"internal"===b&&GTM_UTILS.setCookie("hasEverBeenInternal",!0);var f=["employees/index.aspx","administration/campus-governance/faculty-senate.aspx","administration/campus-governance/staff-senate.aspx","administration/academic-affairs/faculty-handbook/index.aspx"],g=["current-students","become-a-student/admitted-students",
# "administration/academic-affairs/instructional-design-delivery/cms/student-support/index.aspx","administration/academic-affairs/instructional-design-delivery/cms/index.aspx"],h=["alumni/"],k=["administration/parents-family/index.aspx","administration/administration-and-finance-offices/information-technology/help-desk/parents.aspx","salisbury.campusesp.com/users/sign_in","administration/administration-and-finance-offices/physical-plant/post-office/parents-info.aspx"],l=["administration/advancement-and-external-affairs/university-foundation"],
# m=["explore-academics/","become-a-student/","afford-college/","experience-campus/","discover-su/"],a="";switch(!0){case c(d,f):a="Faculty";b="internal";break;case c(d,g):a="Current Student";b="internal";break;case c(d,h):a="Alumni";break;case c(d,k):a="Parent";break;case c(d,l)&&"external"===b:a="Donor";break;case c(d,m)&&"external"===b&&!/Faculty|Current Student/.test(e):a="Prospective Student";break;case "external"===b&&!e:a="Prospective Student";break;case "internal"===b&&!e:a="Other Internal";
# break;default:a=void 0}a&&a!==e&&(GTM_UTILS.setCookie("persona",a),dataLayer.push({event:"persona",persona:a,hasEverBeenInternal:GTM_UTILS.getCookie("hasEverBeenInternal"),visitorLocationType:b}))})();
#   </script>
#   <div class="ui-datepicker ui-widget ui-widget-content ui-helper-clearfix ui-corner-all" id="ui-datepicker-div" style="position: absolute; top: 656.266px; left: 497.094px; z-index: 1; display: block; opacity: 0.00024672;">
#    <div class="ui-datepicker-header ui-widget-header ui-helper-clearfix ui-corner-all">
#     <a class="ui-datepicker-prev ui-corner-all" data-event="click" data-handler="prev" title="Prev">
#      <span class="ui-icon ui-icon-circle-triangle-w">
#       Prev
#      </span>
#     </a>
#     <a class="ui-datepicker-next ui-corner-all" data-event="click" data-handler="next" title="Next">
#      <span class="ui-icon ui-icon-circle-triangle-e">
#       Next
#      </span>
#     </a>
#     <div class="ui-datepicker-title">
#      <span class="ui-datepicker-month">
#       October
#      </span>
#      <span class="ui-datepicker-year">
#       2021
#      </span>
#     </div>
#    </div>
#    <table class="ui-datepicker-calendar">
#     <thead>
#      <tr>
#       <th class="ui-datepicker-week-end">
#        <span title="Sunday">
#         Su
#        </span>
#       </th>
#       <th>
#        <span title="Monday">
#         Mo
#        </span>
#       </th>
#       <th>
#        <span title="Tuesday">
#         Tu
#        </span>
#       </th>
#       <th>
#        <span title="Wednesday">
#         We
#        </span>
#       </th>
#       <th>
#        <span title="Thursday">
#         Th
#        </span>
#       </th>
#       <th>
#        <span title="Friday">
#         Fr
#        </span>
#       </th>
#       <th class="ui-datepicker-week-end">
#        <span title="Saturday">
#         Sa
#        </span>
#       </th>
#      </tr>
#     </thead>
#     <tbody>
#      <tr>
#       <td class="ui-datepicker-week-end ui-datepicker-other-month ui-datepicker-unselectable ui-state-disabled">
#       </td>
#       <td class="ui-datepicker-other-month ui-datepicker-unselectable ui-state-disabled">
#       </td>
#       <td class="ui-datepicker-other-month ui-datepicker-unselectable ui-state-disabled">
#       </td>
#       <td class="ui-datepicker-other-month ui-datepicker-unselectable ui-state-disabled">
#       </td>
#       <td class="ui-datepicker-other-month ui-datepicker-unselectable ui-state-disabled">
#       </td>
#       <td class="" data-event="click" data-handler="selectDay" data-month="9" data-year="2021">
#        <a class="ui-state-default" href="#">
#         1
#        </a>
#       </td>
#       <td class="ui-datepicker-week-end" data-event="click" data-handler="selectDay" data-month="9" data-year="2021">
#        <a class="ui-state-default" href="#">
#         2
#        </a>
#       </td>
#      </tr>
#      <tr>
#       <td class="ui-datepicker-week-end" data-event="click" data-handler="selectDay" data-month="9" data-year="2021">
#        <a class="ui-state-default" href="#">
#         3
#        </a>
#       </td>
#       <td class="" data-event="click" data-handler="selectDay" data-month="9" data-year="2021">
#        <a class="ui-state-default" href="#">
#         4
#        </a>
#       </td>
#       <td class="" data-event="click" data-handler="selectDay" data-month="9" data-year="2021">
#        <a class="ui-state-default" href="#">
#         5
#        </a>
#       </td>
#       <td class="" data-event="click" data-handler="selectDay" data-month="9" data-year="2021">
#        <a class="ui-state-default" href="#">
#         6
#        </a>
#       </td>
#       <td class="" data-event="click" data-handler="selectDay" data-month="9" data-year="2021">
#        <a class="ui-state-default" href="#">
#         7
#        </a>
#       </td>
#       <td class="" data-event="click" data-handler="selectDay" data-month="9" data-year="2021">
#        <a class="ui-state-default" href="#">
#         8
#        </a>
#       </td>
#       <td class="ui-datepicker-week-end" data-event="click" data-handler="selectDay" data-month="9" data-year="2021">
#        <a class="ui-state-default" href="#">
#         9
#        </a>
#       </td>
#      </tr>
#      <tr>
#       <td class="ui-datepicker-week-end" data-event="click" data-handler="selectDay" data-month="9" data-year="2021">
#        <a class="ui-state-default" href="#">
#         10
#        </a>
#       </td>
#       <td class="" data-event="click" data-handler="selectDay" data-month="9" data-year="2021">
#        <a class="ui-state-default" href="#">
#         11
#        </a>
#       </td>
#       <td class="ui-datepicker-days-cell-over ui-datepicker-today" data-event="click" data-handler="selectDay" data-month="9" data-year="2021">
#        <a class="ui-state-default ui-state-highlight ui-state-hover" href="#">
#         12
#        </a>
#       </td>
#       <td class="" data-event="click" data-handler="selectDay" data-month="9" data-year="2021">
#        <a class="ui-state-default" href="#">
#         13
#        </a>
#       </td>
#       <td class="" data-event="click" data-handler="selectDay" data-month="9" data-year="2021">
#        <a class="ui-state-default" href="#">
#         14
#        </a>
#       </td>
#       <td class="" data-event="click" data-handler="selectDay" data-month="9" data-year="2021">
#        <a class="ui-state-default" href="#">
#         15
#        </a>
#       </td>
#       <td class="ui-datepicker-week-end" data-event="click" data-handler="selectDay" data-month="9" data-year="2021">
#        <a class="ui-state-default" href="#">
#         16
#        </a>
#       </td>
#      </tr>
#      <tr>
#       <td class="ui-datepicker-week-end" data-event="click" data-handler="selectDay" data-month="9" data-year="2021">
#        <a class="ui-state-default" href="#">
#         17
#        </a>
#       </td>
#       <td class="" data-event="click" data-handler="selectDay" data-month="9" data-year="2021">
#        <a class="ui-state-default" href="#">
#         18
#        </a>
#       </td>
#       <td class="" data-event="click" data-handler="selectDay" data-month="9" data-year="2021">
#        <a class="ui-state-default" href="#">
#         19
#        </a>
#       </td>
#       <td class="" data-event="click" data-handler="selectDay" data-month="9" data-year="2021">
#        <a class="ui-state-default" href="#">
#         20
#        </a>
#       </td>
#       <td class="" data-event="click" data-handler="selectDay" data-month="9" data-year="2021">
#        <a class="ui-state-default" href="#">
#         21
#        </a>
#       </td>
#       <td class="" data-event="click" data-handler="selectDay" data-month="9" data-year="2021">
#        <a class="ui-state-default" href="#">
#         22
#        </a>
#       </td>
#       <td class="ui-datepicker-week-end" data-event="click" data-handler="selectDay" data-month="9" data-year="2021">
#        <a class="ui-state-default" href="#">
#         23
#        </a>
#       </td>
#      </tr>
#      <tr>
#       <td class="ui-datepicker-week-end" data-event="click" data-handler="selectDay" data-month="9" data-year="2021">
#        <a class="ui-state-default" href="#">
#         24
#        </a>
#       </td>
#       <td class="" data-event="click" data-handler="selectDay" data-month="9" data-year="2021">
#        <a class="ui-state-default" href="#">
#         25
#        </a>
#       </td>
#       <td class="" data-event="click" data-handler="selectDay" data-month="9" data-year="2021">
#        <a class="ui-state-default" href="#">
#         26
#        </a>
#       </td>
#       <td class="" data-event="click" data-handler="selectDay" data-month="9" data-year="2021">
#        <a class="ui-state-default" href="#">
#         27
#        </a>
#       </td>
#       <td class="" data-event="click" data-handler="selectDay" data-month="9" data-year="2021">
#        <a class="ui-state-default" href="#">
#         28
#        </a>
#       </td>
#       <td class="" data-event="click" data-handler="selectDay" data-month="9" data-year="2021">
#        <a class="ui-state-default" href="#">
#         29
#        </a>
#       </td>
#       <td class="ui-datepicker-week-end" data-event="click" data-handler="selectDay" data-month="9" data-year="2021">
#        <a class="ui-state-default" href="#">
#         30
#        </a>
#       </td>
#      </tr>
#      <tr>
#       <td class="ui-datepicker-week-end" data-event="click" data-handler="selectDay" data-month="9" data-year="2021">
#        <a class="ui-state-default" href="#">
#         31
#        </a>
#       </td>
#       <td class="ui-datepicker-other-month ui-datepicker-unselectable ui-state-disabled">
#       </td>
#       <td class="ui-datepicker-other-month ui-datepicker-unselectable ui-state-disabled">
#       </td>
#       <td class="ui-datepicker-other-month ui-datepicker-unselectable ui-state-disabled">
#       </td>
#       <td class="ui-datepicker-other-month ui-datepicker-unselectable ui-state-disabled">
#       </td>
#       <td class="ui-datepicker-other-month ui-datepicker-unselectable ui-state-disabled">
#       </td>
#       <td class="ui-datepicker-week-end ui-datepicker-other-month ui-datepicker-unselectable ui-state-disabled">
#       </td>
#      </tr>
#     </tbody>
#    </table>
#   </div>
#   <script id="" type="text/javascript">
#    var _komito=_komito||{trackTwitter:1,trackFacebook:1,trackLinkedIn:1,trackDownloads:1,trackOutbound:1,trackForms:1,trackUsers:1,trackActions:1,trackPrint:0,trackMedia:1,trackScroll:1,trackOrientation:1,trackAdblock:0,debugMode:0,nonInteraction:"form print scroll video orientation adblock".split(" ")};
#   </script>
#   <iframe data-gtm-yt-inspected-1_25="true" src="https://bid.g.doubleclick.net/xbbe/pixel?d=KAE" style="display: none;">
#   </iframe>
#   <iframe data-gtm-yt-inspected-1_25="true" src="https://bid.g.doubleclick.net/xbbe/pixel?d=KAE" style="display: none;">
#   </iframe>
#  </body>
# </html>
